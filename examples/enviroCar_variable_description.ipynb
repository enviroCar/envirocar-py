# %%
import pandas as pd
pd.set_option('display.max_columns', None)
import geopandas as gpd
import numpy as np
from envirocar import TrackAPI, DownloadClient, BboxSelector, ECConfig
config = ECConfig()
track_api = TrackAPI(api_client=DownloadClient(config=config))
bbox = BboxSelector([
    7.554130554199218, # min_x
    51.95590322041212, # min_y
    7.590351104736328, # max_x
    51.97874790276371  # max_y
])

# issue a query with 40 tracks
track_df = track_api.get_tracks(bbox=bbox, num_results=100) 

# issue a query for just one track made by an e-car
track_api.get_track('5f17fa6dd2ad470001e79748')
# Out:
#                            id                       time  \
# 0    5f17fa6dd2ad470001e7974a  2020-07-10T07:14:49+00:00
# 1    5f17fa6dd2ad470001e7974c  2020-07-10T07:14:54+00:00
# 2    5f17fa6dd2ad470001e7974d  2020-07-10T07:15:03+00:00
# 3    5f17fa6dd2ad470001e7974e  2020-07-10T07:15:08+00:00
# 4    5f17fa6dd2ad470001e7974f  2020-07-10T07:15:23+00:00
# ..                        ...                        ...
# 731  5f17fa6dd2ad470001e79a26  2020-07-10T08:34:38+00:00
# 732  5f17fa6dd2ad470001e79a27  2020-07-10T08:34:43+00:00
# 733  5f17fa6dd2ad470001e79a28  2020-07-10T08:34:48+00:00
# 734  5f17fa6dd2ad470001e79a29  2020-07-10T08:34:53+00:00
# 735  5f17fa6dd2ad470001e79a2a  2020-07-10T08:34:58+00:00
#
#                      geometry  Speed.value Speed.unit  \
# 0    POINT (7.80929 51.68009)    -0.500000       km/h
# 1    POINT (7.80930 51.68009)    -1.000000       km/h
# 2    POINT (7.80919 51.68007)     3.111111       km/h
# 3    POINT (7.80905 51.68016)    10.000000       km/h
# 4    POINT (7.80930 51.68075)    20.095238       km/h
# ..                        ...          ...        ...
# 731  POINT (6.96976 51.55529)    -2.000000       km/h
# 732  POINT (6.96976 51.55529)    -2.000000       km/h
# 733  POINT (6.96976 51.55529)    -2.000000       km/h
# 734  POINT (6.96976 51.55529)    -2.000000       km/h
# 735  POINT (6.96976 51.55529)    -2.000000       km/h
#
#      Energy Consumption.value Energy Consumption.unit  \
# 0                         1.0                      kW
# 1                         0.0                      kW
# 2                         0.0                      kW
# 3                         0.0                      kW
# 4                        -1.0                      kW
# ..                        ...                     ...
# 731                       0.0                      kW
# 732                       0.0                      kW
# 733                       0.0                      kW
# 734                       0.0                      kW
# 735                       0.0                      kW
#
#                      track.id  track.length           track.begin  \
# 0    5f17fa6dd2ad470001e79748     68.912519  2020-07-10T07:14:49Z
# 1    5f17fa6dd2ad470001e79748     68.912519  2020-07-10T07:14:49Z
# 2    5f17fa6dd2ad470001e79748     68.912519  2020-07-10T07:14:49Z
# 3    5f17fa6dd2ad470001e79748     68.912519  2020-07-10T07:14:49Z
# 4    5f17fa6dd2ad470001e79748     68.912519  2020-07-10T07:14:49Z
# ..                        ...           ...                   ...
# 731  5f17fa6dd2ad470001e79748     68.912519  2020-07-10T07:14:49Z
# 732  5f17fa6dd2ad470001e79748     68.912519  2020-07-10T07:14:49Z
# 733  5f17fa6dd2ad470001e79748     68.912519  2020-07-10T07:14:49Z
# 734  5f17fa6dd2ad470001e79748     68.912519  2020-07-10T07:14:49Z
# 735  5f17fa6dd2ad470001e79748     68.912519  2020-07-10T07:14:49Z
#
#                 track.end track.touVersion sensor.type sensor.model  \
# 0    2020-07-10T08:34:58Z       2019-07-14         car          ZOE
# 1    2020-07-10T08:34:58Z       2019-07-14         car          ZOE
# 2    2020-07-10T08:34:58Z       2019-07-14         car          ZOE
# 3    2020-07-10T08:34:58Z       2019-07-14         car          ZOE
# 4    2020-07-10T08:34:58Z       2019-07-14         car          ZOE
# ..                    ...              ...         ...          ...
# 731  2020-07-10T08:34:58Z       2019-07-14         car          ZOE
# 732  2020-07-10T08:34:58Z       2019-07-14         car          ZOE
# 733  2020-07-10T08:34:58Z       2019-07-14         car          ZOE
# 734  2020-07-10T08:34:58Z       2019-07-14         car          ZOE
# 735  2020-07-10T08:34:58Z       2019-07-14         car          ZOE
#
#                     sensor.id sensor.fuelType  sensor.constructionYear  \
# 0    5ef5e1b0d2ad470001520cd5        electric                     2017
# 1    5ef5e1b0d2ad470001520cd5        electric                     2017
# 2    5ef5e1b0d2ad470001520cd5        electric                     2017
# 3    5ef5e1b0d2ad470001520cd5        electric                     2017
# 4    5ef5e1b0d2ad470001520cd5        electric                     2017
# ..                        ...             ...                      ...
# 731  5ef5e1b0d2ad470001520cd5        electric                     2017
# 732  5ef5e1b0d2ad470001520cd5        electric                     2017
# 733  5ef5e1b0d2ad470001520cd5        electric                     2017
# 734  5ef5e1b0d2ad470001520cd5        electric                     2017
# 735  5ef5e1b0d2ad470001520cd5        electric                     2017
#
#     sensor.manufacturer
# 0               Renault
# 1               Renault
# 2               Renault
# 3               Renault
# 4               Renault
# ..                  ...
# 731             Renault
# 732             Renault
# 733             Renault
# 734             Renault
# 735             Renault
#
# [736 rows x 18 columns]

# %%
track = track_api.get_track('5f17fa6dd2ad470001e79748')
track['Energy Consumption.value'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## 0. Example
# Here, you see an example dataframe as how you will receive when using the envirocar-py package to request multiple tracks via the enviroCar API.

# %%
track_df.head()
# Out:
#                          id                       time  \
# 0  5f0ef89c00375c5a2641ef86  2020-07-15T12:37:03+00:00
# 1  5f0ef89c00375c5a2641ef88  2020-07-15T12:37:09+00:00
# 2  5f0ef89c00375c5a2641ef89  2020-07-15T12:37:14+00:00
# 3  5f0ef89c00375c5a2641ef8a  2020-07-15T12:37:19+00:00
# 4  5f0ef89c00375c5a2641ef8b  2020-07-15T12:37:24+00:00
#
#                    geometry  Engine Load.value Engine Load.unit  \
# 0  POINT (7.57939 51.96766)          30.459892                %
# 1  POINT (7.57955 51.96757)          49.230105                %
# 2  POINT (7.57988 51.96740)          78.649652                %
# 3  POINT (7.58049 51.96715)          31.200400                %
# 4  POINT (7.58107 51.96682)          29.735773                %
#
#    Calculated MAF.value Calculated MAF.unit  Speed.value Speed.unit  \
# 0              3.113889                 g/s    15.978930       km/h
# 1              9.778811                 g/s    11.134565       km/h
# 2             25.066406                 g/s    33.976330       km/h
# 3              7.419664                 g/s    39.000000       km/h
# 4              3.106679                 g/s    34.321667       km/h
#
#    CO2.value CO2.unit  Intake Pressure.value Intake Pressure.unit  \
# 0   2.405470     kg/h              29.667201                  kPa
# 1   7.554102     kg/h              47.232322                  kPa
# 2  19.363722     kg/h              74.040426                  kPa
# 3   5.731668     kg/h              30.075758                  kPa
# 4   2.399900     kg/h              29.000000                  kPa
#
#      Rpm.value Rpm.unit  Intake Temperature.value Intake Temperature.unit  \
# 0   748.952252    u/min                 26.000000                       c
# 1  1475.604745    u/min                 25.652838                       c
# 2  2397.395931    u/min                 23.728013                       c
# 3  1748.565672    u/min                 24.000000                       c
# 4   761.854074    u/min                 25.000000                       c
#
#    Consumption (GPS-based).value Consumption (GPS-based).unit  \
# 0                       0.936199                          l/h
# 1                       0.937457                          l/h
# 2                       5.102906                          l/h
# 3                       2.280491                          l/h
# 4                       0.946257                          l/h
#
#    GPS Altitude.value GPS Altitude.unit  Throttle Position.value  \
# 0          115.671012                 m                13.000000
# 1          115.280639                 m                16.642229
# 2          114.613231                 m                23.862069
# 3          113.835218                 m                15.351261
# 4          113.502384                 m                13.000000
#
#   Throttle Position.unit  GPS Bearing.value GPS Bearing.unit  \
# 0                      %         136.590329              deg
# 1                      %         134.479803              deg
# 2                      %         123.313954              deg
# 3                      %         125.035780              deg
# 4                      %         133.482068              deg
#
#    Consumption.value Consumption.unit  GPS Accuracy.value GPS Accuracy.unit  \
# 0           1.023604              l/h            6.000000                 %
# 1           3.214511              l/h            6.000000                 %
# 2           8.239881              l/h            6.193485                 %
# 3           2.439007              l/h            6.000000                 %
# 4           1.021234              l/h            7.489919                 %
#
#    CO2 Emission (GPS-based).value CO2 Emission (GPS-based).unit  \
# 0                        2.200068                          kg/h
# 1                        2.203025                          kg/h
# 2                       11.991830                          kg/h
# 3                        5.359154                          kg/h
# 4                        2.223704                          kg/h
#
#    GPS Speed.value GPS Speed.unit                  track.id  track.length  \
# 0        17.502660           km/h  5f0ef89c00375c5a2641ef84      0.665466
# 1        10.324164           km/h  5f0ef89c00375c5a2641ef84      0.665466
# 2        30.967132           km/h  5f0ef89c00375c5a2641ef84      0.665466
# 3        36.898346           km/h  5f0ef89c00375c5a2641ef84      0.665466
# 4        34.447545           km/h  5f0ef89c00375c5a2641ef84      0.665466
#
#             track.begin             track.end sensor.type  \
# 0  2020-07-15T12:37:03Z  2020-07-15T12:38:25Z         car
# 1  2020-07-15T12:37:03Z  2020-07-15T12:38:25Z         car
# 2  2020-07-15T12:37:03Z  2020-07-15T12:38:25Z         car
# 3  2020-07-15T12:37:03Z  2020-07-15T12:38:25Z         car
# 4  2020-07-15T12:37:03Z  2020-07-15T12:38:25Z         car
#
#    sensor.engineDisplacement sensor.model                 sensor.id  \
# 0                       1699        A 170  559e22c2e4b07207d8977998
# 1                       1699        A 170  559e22c2e4b07207d8977998
# 2                       1699        A 170  559e22c2e4b07207d8977998
# 3                       1699        A 170  559e22c2e4b07207d8977998
# 4                       1699        A 170  559e22c2e4b07207d8977998
#
#   sensor.fuelType  sensor.constructionYear sensor.manufacturer  \
# 0        gasoline                     2004       Mercedes Benz
# 1        gasoline                     2004       Mercedes Benz
# 2        gasoline                     2004       Mercedes Benz
# 3        gasoline                     2004       Mercedes Benz
# 4        gasoline                     2004       Mercedes Benz
#
#   track.appVersion track.touVersion  GPS HDOP.value GPS HDOP.unit  \
# 0              NaN              NaN             NaN           NaN
# 1              NaN              NaN             NaN           NaN
# 2              NaN              NaN             NaN           NaN
# 3              NaN              NaN             NaN           NaN
# 4              NaN              NaN             NaN           NaN
#
#    GPS PDOP.value GPS PDOP.unit  GPS VDOP.value GPS VDOP.unit  MAF.value  \
# 0             NaN           NaN             NaN           NaN        NaN
# 1             NaN           NaN             NaN           NaN        NaN
# 2             NaN           NaN             NaN           NaN        NaN
# 3             NaN           NaN             NaN           NaN        NaN
# 4             NaN           NaN             NaN           NaN        NaN
#
#   MAF.unit  O2 Lambda Voltage ER.value O2 Lambda Voltage ER.unit  \
# 0      NaN                         NaN                       NaN
# 1      NaN                         NaN                       NaN
# 2      NaN                         NaN                       NaN
# 3      NaN                         NaN                       NaN
# 4      NaN                         NaN                       NaN
#
#    O2 Lambda Voltage.value O2 Lambda Voltage.unit  O2 Lambda Current ER.value  \
# 0                      NaN                    NaN                         NaN
# 1                      NaN                    NaN                         NaN
# 2                      NaN                    NaN                         NaN
# 3                      NaN                    NaN                         NaN
# 4                      NaN                    NaN                         NaN
#
#   O2 Lambda Current ER.unit  O2 Lambda Current.value O2 Lambda Current.unit  \
# 0                       NaN                      NaN                    NaN
# 1                       NaN                      NaN                    NaN
# 2                       NaN                      NaN                    NaN
# 3                       NaN                      NaN                    NaN
# 4                       NaN                      NaN                    NaN
#
#    Short-Term Fuel Trim 1.value Short-Term Fuel Trim 1.unit  \
# 0                           NaN                         NaN
# 1                           NaN                         NaN
# 2                           NaN                         NaN
# 3                           NaN                         NaN
# 4                           NaN                         NaN
#
#    Long-Term Fuel Trim 1.value Long-Term Fuel Trim 1.unit
# 0                          NaN                        NaN
# 1                          NaN                        NaN
# 2                          NaN                        NaN
# 3                          NaN                        NaN
# 4                          NaN                        NaN

# %% [markdown]
# ## 1. All variables which you receive when requesting data via the enviroCar API
# Below you see all available variables and its datatype. Not all tracks provide the full set of data, therefore, dependent on the tracks you receive, the set on variables may be smaller.
# You will notice that there are variables which end with '.value' or with '.unit'. While variables which end with '.value' actually hold values, variables ending with '.unit' hold the unit information relevant for the variable.

# %%
columnname=[]
datatype=[]
for column in track_df:
    columnname.append(column) 
    datatype.append(track_df[column].dtype)
d = {'column name':columnname, 'data type':datatype}
pd.DataFrame(d)
# Out:
#                      column name data type
# 0                             id    object
# 1                           time    object
# 2                       geometry  geometry
# 3              Engine Load.value   float64
# 4               Engine Load.unit    object
# ..                           ...       ...
# 61        O2 Lambda Current.unit    object
# 62  Short-Term Fuel Trim 1.value   float64
# 63   Short-Term Fuel Trim 1.unit    object
# 64   Long-Term Fuel Trim 1.value   float64
# 65    Long-Term Fuel Trim 1.unit    object
#
# [66 rows x 2 columns]

# %%
from eda_quality import manipulation as manipulate

manipulate.drop_unit_columns(track_df)



columnname=[]
datatype=[]
for column in track_df:
    columnname.append(column) 
    datatype.append(track_df[column].dtype)
columnname.append('Energy Consumption.value')
datatype.append('float64')
d = {'column name':columnname, 'data type':datatype}
d = pd.DataFrame(d)

d.index += 1 
d
# Out:
# Dropped unit columns:  Index([], dtype='object')
#                        column name data type
# 1                               id    object
# 2                             time    object
# 3                         geometry  geometry
# 4                Engine Load.value   float64
# 5             Calculated MAF.value   float64
# 6                      Speed.value   float64
# 7                        CO2.value   float64
# 8            Intake Pressure.value   float64
# 9                        Rpm.value   float64
# 10        Intake Temperature.value   float64
# 11   Consumption (GPS-based).value   float64
# 12              GPS Altitude.value   float64
# 13         Throttle Position.value   float64
# 14               GPS Bearing.value   float64
# 15               Consumption.value   float64
# 16              GPS Accuracy.value   float64
# 17  CO2 Emission (GPS-based).value   float64
# 18                 GPS Speed.value   float64
# 19                        track.id    object
# 20                    track.length   float64
# 21                     track.begin    object
# 22                       track.end    object
# 23                     sensor.type    object
# 24       sensor.engineDisplacement     int64
# 25                    sensor.model    object
# 26                       sensor.id    object
# 27                 sensor.fuelType    object
# 28         sensor.constructionYear     int64
# 29             sensor.manufacturer    object
# 30                track.appVersion    object
# 31                track.touVersion    object
# 32                  GPS HDOP.value   float64
# 33                  GPS PDOP.value   float64
# 34                  GPS VDOP.value   float64
# 35                       MAF.value   float64
# 36      O2 Lambda Voltage ER.value   float64
# 37         O2 Lambda Voltage.value   float64
# 38      O2 Lambda Current ER.value   float64
# 39         O2 Lambda Current.value   float64
# 40    Short-Term Fuel Trim 1.value   float64
# 41     Long-Term Fuel Trim 1.value   float64
# 42        Energy Consumption.value   float64

# %% [markdown]
# ### 1.1 Units of variables
# Here you can inspect the units of the numerical variables.

# %%
print('VARIABLE [UNIT]')
print('---')
units = track_df.filter(like='.unit').columns
for unit in units:
    if unit in track_df:
        print(track_df[unit].name, track_df[unit].dropna().unique())
# Out:
# VARIABLE [UNIT]
# ---

# %% [markdown]
# ### 1.2 OBD based data
# Following numeric variables are recorded by the OBD

# %%
OBD = track_df[['Engine Load.value','Rpm.value', 
                'Intake Pressure.value', 'Intake Temperature.value', 
                'Speed.value','Throttle Position.value', 'MAF.value', 
                'O2 Lambda Voltage ER.value', 'O2 Lambda Voltage.value']]

print('OBD BASED DATA')
print('---')
for column in OBD:
    print(column)
# Out:
# OBD BASED DATA
# ---
# Engine Load.value
# Rpm.value
# Intake Pressure.value
# Intake Temperature.value
# Speed.value
# Throttle Position.value
# MAF.value
# O2 Lambda Voltage ER.value
# O2 Lambda Voltage.value

# %% [markdown]
# ### 1.3 GPS based data
# The following numeric variables are recorded by the GPS-Sensor

# %%
GPS = track_df[['geometry','GPS Accuracy.value','GPS Altitude.value', 
                'GPS Bearing.value', 'GPS HDOP.value', 
                'GPS PDOP.value','GPS Speed.value', 'GPS VDOP.value']]

print('GPS BASED DATA')
print('---')
for column in GPS:
    print(column)
# Out:
# GPS BASED DATA
# ---
# geometry
# GPS Accuracy.value
# GPS Altitude.value
# GPS Bearing.value
# GPS HDOP.value
# GPS PDOP.value
# GPS Speed.value
# GPS VDOP.value

# %% [markdown]
# ## 2. Geometry variable
# As the data comes as geodataframe it contains a geometry variable, which is in this case a point geometry, for each measurement a single point geometry which contains latitude and longitude coordinates.

# %%
print('GEOMETRY VARIABLE')
print('---')
geomV=track_df[['geometry']]
for column in geomV:
    print(column)
# Out:
# GEOMETRY VARIABLE
# ---
# geometry

# %% [markdown]
# See example point geometries below:

# %%
geomV.head()
# Out:
#                    geometry
# 0  POINT (7.57939 51.96766)
# 1  POINT (7.57955 51.96757)
# 2  POINT (7.57988 51.96740)
# 3  POINT (7.58049 51.96715)
# 4  POINT (7.58107 51.96682)

# %% [markdown]
# ## 3. Numeric variables
# There are two types of numeric variables: integer 64 and float 64.

# %% [markdown]
# ### 3.1 Variables from datatype:  float64
# Most variables are from datatype float64.
# Some variables are the result from calculations based on enviroCar data.
#
# The following variables are calculated based on enviroCar data:
# - <b> Calculated MAF.value <b>
# - Consumption.value
# - CO2.value
# - CO2 Emission (GPS-based).value
# - Consumption (GPS-based).value
#
# For detailed information on the calculations please refer to the following two 52°North blog posts:
# https://blog.52north.org/2020/07/02/fuel-consumption-models-in-envirocar/
# https://blog.52north.org/2020/04/01/estimating-fuel-consumption-of-cars/

# %%
print('NUMERIC VARIABLES FLOAT64:')
print('---')
for column in track_df.select_dtypes(['float64']):
    print(column)
# Out:
# NUMERIC VARIABLES FLOAT64:
# ---
# Engine Load.value
# Calculated MAF.value
# Speed.value
# CO2.value
# Intake Pressure.value
# Rpm.value
# Intake Temperature.value
# Consumption (GPS-based).value
# GPS Altitude.value
# Throttle Position.value
# GPS Bearing.value
# Consumption.value
# GPS Accuracy.value
# CO2 Emission (GPS-based).value
# GPS Speed.value
# track.length
# GPS HDOP.value
# GPS PDOP.value
# GPS VDOP.value
# MAF.value
# O2 Lambda Voltage ER.value
# O2 Lambda Voltage.value
# O2 Lambda Current ER.value
# O2 Lambda Current.value
# Short-Term Fuel Trim 1.value
# Long-Term Fuel Trim 1.value

# %% [markdown]
# ### 3.2 Variables from datatype:  Int64
# The following variables are the only integer64 types in the data

# %%
print('NUMERIC VARIABLES INT64:')
print('---')
for column in track_df.select_dtypes(['int64']):
    print(column)
# Out:
# NUMERIC VARIABLES INT64:
# ---
# sensor.engineDisplacement
# sensor.constructionYear

# %% [markdown]
# ## 4. Object variables
# The following variables are objects, i.e. strings:

# %%
print('OBJECT VARIABLES')
print('---')
units = track_df.filter(like='.unit').columns.to_list()
for column in track_df.select_dtypes(['object']):
    if column not in units:
        print(track_df[column].name)
# Out:
# OBJECT VARIABLES
# ---
# id
# time
# track.id
# track.begin
# track.end
# sensor.type
# sensor.model
# sensor.id
# sensor.fuelType
# sensor.manufacturer
# track.appVersion
# track.touVersion

# %% [markdown]
# ### 4.1 Categorical variables
# Categorical variables are here defined as object variables which are no indices. Further they are of ordinal type and provide, well, categories :)

# %%
print('CATEGORICAL VARIABLES')
print('---')
catV=track_df[['sensor.type', 'sensor.model', 'sensor.fuelType', 'sensor.manufacturer',
               'track.appVersion', 'track.touVersion']]
for column in catV:
    print(column)
# Out:
# CATEGORICAL VARIABLES
# ---
# sensor.type
# sensor.model
# sensor.fuelType
# sensor.manufacturer
# track.appVersion
# track.touVersion

# %% [markdown]
# ### 4.2 Indices
# There are two indices which are relevant for the track and measurement identification:
# <b>track.id : each track has a unique track.id
# id: each measurement within a certain track has a unique id. This id is also unique in the whole sample

# %%
print('INDICES')
print('---')
indicesV=track_df[['id','track.id']]
for column in indicesV:
    print(column)
# Out:
# INDICES
# ---
# id
# track.id

# %% [markdown]
# ### 4.3 Time variables
# There are three object variables related to time:
# <b>time: time stamp of data point
# track.begin: timestamp of first measurement of the track
# track.end: timestamp of last measurement of the track

# %%
print('TIME VARIABLES')
print('---')
timeV=track_df[['time','track.begin','track.end']]
for column in timeV:
    print(column)
# Out:
# TIME VARIABLES
# ---
# time
# track.begin
# track.end
