# %% [markdown]
# # Fuel consumption - python toolbox

# %% [markdown]
# We have developed a tool to let the user define the parameters of the car, the route and the boundry of his study area, to get the fuel consumption/Co2 emissions on the route.

# %% [markdown]
# ## Load packages

# %% [markdown]
# The user have to import consumption function and car class.

# %%
from envirocar import TrackAPI,consumption, DownloadClient, BboxSelector, TimeSelector, ECConfig, car

# create an initial but optional config and an api client
config = ECConfig()
track_api = TrackAPI(api_client=DownloadClient(config=config))

# %%
import warnings
warnings.filterwarnings('ignore')
warnings.simplefilter('ignore')

# %% [markdown]
# ## Query tracks

# %%
bbox = BboxSelector([
    7.603312, # min_x
    51.952343, # min_y
    7.65083, # max_x 
    51.974045,  # max_y 
])


# issue a query
track_df = track_api.get_tracks(bbox=bbox,  num_results=10)
# Out:
# <envirocar.client.request_param.RequestParam object at 0x0000024DF7CE1208>

# %%
## Select a track
one_track_id = track_df['track.id'].unique()[8]
track = track_df[track_df['track.id'] == one_track_id]
track
# Out:
#                            id                 time                  geometry  \
# 0    5eb7582165b80c5d6be6a144  2020-05-09T08:12:25  POINT (7.65306 51.97227)
# 1    5eb7582165b80c5d6be6a146  2020-05-09T08:12:30  POINT (7.65311 51.97235)
# 2    5eb7582165b80c5d6be6a147  2020-05-09T08:12:35  POINT (7.65294 51.97243)
# 3    5eb7582165b80c5d6be6a148  2020-05-09T08:12:40  POINT (7.65250 51.97243)
# 4    5eb7582165b80c5d6be6a149  2020-05-09T08:12:45  POINT (7.65211 51.97231)
# ..                        ...                  ...                       ...
# 105  5eb7582165b80c5d6be6a1ae  2020-05-09T08:21:15  POINT (7.65199 51.95401)
# 106  5eb7582165b80c5d6be6a1af  2020-05-09T08:21:20  POINT (7.65183 51.95399)
# 107  5eb7582165b80c5d6be6a1b0  2020-05-09T08:21:25  POINT (7.65180 51.95398)
# 108  5eb7582165b80c5d6be6a1b1  2020-05-09T08:21:30  POINT (7.65180 51.95398)
# 109  5eb7582165b80c5d6be6a1b2  2020-05-09T08:21:35  POINT (7.65180 51.95398)
#
#      Consumption.value Consumption.unit  GPS Altitude.value GPS Altitude.unit  \
# 0             3.576507              l/h          109.000000                 m
# 1             2.084501              l/h          111.157954                 m
# 2             3.138700              l/h          110.714431                 m
# 3             3.306664              l/h          108.000003                 m
# 4             4.313685              l/h          105.667613                 m
# ..                 ...              ...                 ...               ...
# 105           1.636909              l/h          106.000000                 m
# 106           1.601665              l/h          105.000000                 m
# 107           1.569227              l/h          105.000000                 m
# 108           1.608655              l/h          105.000000                 m
# 109                NaN              NaN          105.000001                 m
#
#      Throttle Position.value Throttle Position.unit  GPS Accuracy.value  ...  \
# 0                  18.000000                      %            2.093476  ...
# 1                  16.000000                      %            2.078976  ...
# 2                  17.000000                      %            2.500000  ...
# 3                  17.709184                      %            2.500000  ...
# 4                  18.341146                      %            2.666192  ...
# ..                       ...                    ...                 ...  ...
# 105                15.000000                      %            3.500000  ...
# 106                14.000000                      %            3.500000  ...
# 107                14.000000                      %            3.000000  ...
# 108                14.000000                      %            3.000000  ...
# 109                      NaN                    NaN            3.000000  ...
#
#                     sensor.id  sensor.fuelType sensor.constructionYear  \
# 0    58395f40e4b0a979d45bd61b         gasoline                    2007
# 1    58395f40e4b0a979d45bd61b         gasoline                    2007
# 2    58395f40e4b0a979d45bd61b         gasoline                    2007
# 3    58395f40e4b0a979d45bd61b         gasoline                    2007
# 4    58395f40e4b0a979d45bd61b         gasoline                    2007
# ..                        ...              ...                     ...
# 105  58395f40e4b0a979d45bd61b         gasoline                    2007
# 106  58395f40e4b0a979d45bd61b         gasoline                    2007
# 107  58395f40e4b0a979d45bd61b         gasoline                    2007
# 108  58395f40e4b0a979d45bd61b         gasoline                    2007
# 109  58395f40e4b0a979d45bd61b         gasoline                    2007
#
#      sensor.manufacturer GPS VDOP.value  GPS VDOP.unit GPS PDOP.value  \
# 0                  Dodge       0.961303      precision       1.000000
# 1                  Dodge       0.800000      precision       1.000000
# 2                  Dodge       0.800000      precision       0.857994
# 3                  Dodge       0.800000      precision       0.868254
# 4                  Dodge       0.800000      precision       0.800000
# ..                   ...            ...            ...            ...
# 105                Dodge       0.912846      precision       1.000000
# 106                Dodge       0.800000      precision       1.000000
# 107                Dodge       0.800000      precision       1.000000
# 108                Dodge       0.800000      precision       1.000000
# 109                Dodge       0.800000      precision       1.000000
#
#      GPS PDOP.unit GPS HDOP.value  GPS HDOP.unit
# 0        precision       0.400000      precision
# 1        precision       0.400000      precision
# 2        precision       0.400000      precision
# 3        precision       0.400000      precision
# 4        precision       0.400000      precision
# ..             ...            ...            ...
# 105      precision       0.512846      precision
# 106      precision       0.400000      precision
# 107      precision       0.470411      precision
# 108      precision       0.400000      precision
# 109      precision       0.400402      precision
#
# [110 rows x 50 columns]

# %% [markdown]
# ## Call the function to calculate the fuel consumption rate (l/h) and Co2 emissions on the selected track

# %% [markdown]
# In the following function, the user must define the car's parameters, the boundry of osm network (it can be the same area of request tracks) and the tracks/routes in dataframe format. In the folowing cell OSM boundry is the same of the boundry box of quired tracks.
#
# The  reults will be a dataframe with fuel consumption rate (l/h) and Co2 emissions, as well as the neccessary parameters that calculated to get the results.

# %%
land_rover = car(mass=1200, car_cross_sectional=2.5, Air_drag_cofficient=0.4, Calorific_value= 9.8, Idle_power= 1.5)

# %%
instantaneous_consumption = consumption.fuel_consumption(car = land_rover,osmbox = bbox, track_df= track)

# %%
instantaneous_consumption
# Out:
#      elevation  accumulate_time_interval maxspeed  Acceleration  surface  \
# 0    59.104404                       0.0       30           inf  asphalt
# 1    59.157837                       5.0       30      0.323225  asphalt
# 2    58.962212                      10.0       30      0.321799  asphalt
# 3    58.622696                      15.0       30     -0.046771  asphalt
# 4    58.584042                      20.0       30      0.429804  asphalt
# ..         ...                       ...      ...           ...      ...
# 105  62.591785                     530.0       30     -0.340311  asphalt
# 106  62.690655                     535.0       30     -0.258497  asphalt
# 107  62.706928                     540.0       30      0.000000  asphalt
# 108  62.706928                     545.0       30      0.000000  asphalt
# 109  62.706940                     550.0       30           NaN  asphalt
#
#      rolling_resistance  gradient  efficiency  Consumption_Gasoline  \
# 0                  0.02  0.006109    0.300000              0.510204
# 1                  0.02 -0.013473    0.285177              0.450646
# 2                  0.02 -0.011177    0.287583              0.764801
# 3                  0.02 -0.001279    0.263891              0.423299
# 4                  0.02 -0.001937    0.306080              1.415040
# ..                  ...       ...         ...                   ...
# 105                0.02  0.008860    0.245255              0.624091
# 106                0.02  0.007377    0.250981              0.006871
# 107                0.02  0.000000    0.267658              0.571854
# 108                0.02  0.000157    0.267797              0.571558
# 109                0.02       NaN         NaN                   NaN
#
#      CO2_Gasoline
# 0        5.000000
# 1        4.416328
# 2        7.495048
# 3        4.148328
# 4       13.867389
# ..            ...
# 105      6.116090
# 106      0.067337
# 107      5.604167
# 108      5.601268
# 109           NaN
#
# [110 rows x 10 columns]
